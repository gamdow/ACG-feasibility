# %%
class Struct(object):
    def __init__(self, kwargs):
        for k, v in kwargs.items():
            self.__dict__[k] = Struct(v) if isinstance(v, dict) else v
            
settings = Struct({'A': 0,
 'D': 0,
 'H': (0.0, 0.0, 100.0),
 'Hdir': (0, 0, 1),
 'Hmag': 100.0,
 'K': 0,
 'Ms': 800000.0,
 'alpha': 0.8,
 'correction': 0,
 'e': (1, 0, 0),
 'frames': 10,
 'gamma0': 221100.0,
 'grid': {'d': (1e-09, 1e-09, 1e-09),
  'l': (1.0000000000000001e-07, 5.0000000000000004e-08, 1e-08),
  'n': (100, 50, 10)},
 'init': 'flower',
 'mu0': 1.2566370614e-06,
 'periodic_boundary': True,
 'save_every': 100,
 'time': {'d': 1e-14, 'l': 1e-11, 'n': 1000},
 'value': None})

# %%
import os
import sys

if not "DEVITO_OPENMP" in os.environ or os.environ["DEVITO_OPENMP"] != "1":
    print("*** WARNING: Devito OpenMP environment variable has not been set ***", file=sys.stderr)
os.environ['OMP_NUM_THREADS'] = "8"

import numpy as np
from sympy import Matrix, Eq, solve
from devito import Grid, Function, TimeFunction, configuration, Operator

def vector_laplacian(u):
    return Matrix([u[0].dx2 + u[0].dy2 + u[0].dz2,
                   u[1].dx2 + u[1].dy2 + u[1].dz2,
                   u[2].dx2 + u[2].dy2 + u[2].dz2])

def vector_gradient(u):
    return u[0].dx**2 + u[0].dy**2 + u[0].dz**2 + u[1].dx**2 + u[1].dy**2 + u[1].dz**2 + u[2].dx**2 + u[2].dy**2 + u[2].dz**2

def curl(u):
    return Matrix([u[2].dy - u[1].dz,
                   u[0].dz - u[2].dx,
                   u[1].dx - u[0].dy])

def VectorTimeFunction(name, settings):
    return Matrix([TimeFunction(name='{}_x'.format(name), **settings), TimeFunction(name='{}_y'.format(name), **settings), TimeFunction(name='{}_z'.format(name), **settings)])


def VectorDenseFunction(name, settings):
    return Matrix([Function(name='{}_x'.format(name), **settings), Function(name='{}_y'.format(name), **settings), Function(name='{}_z'.format(name), **settings)])

buffer_params = Struct({'buffer_dims': (102, 52, 12),
 'buffer_slice': (slice(1, -1, None), slice(1, -1, None), slice(1, -1, None)),
 'data_dims': (100, 50, 10)})

# %%
RKc = [[0, 0, 0], [0.5, 0, 0], [2, 1, 0], [1/6, 2/3, 1/6]]

grid = Grid(shape=buffer_params.buffer_dims, extent=settings.grid.l)
m = VectorTimeFunction('m', {"grid":grid, "space_order":2})

k = []
temp = []
for i in range(len(RKc) - 1):
    k.append(VectorDenseFunction('k{}'.format(i + 1), {"grid":grid, "space_order":2}))
    temp.append(VectorDenseFunction('temp{}'.format(i + 1), {"grid":grid, "space_order":2}))
    
import sympy 

nx, ny, nz = buffer_params.buffer_dims
dt = settings.time.d
x, y, z = grid.dimensions
update = []


for i, (ki, ti) in enumerate(zip(k, temp)):
    for j, mj in enumerate(m):
        update.append(Eq(ti[j], mj + dt * Matrix(RKc[i]).dot(Matrix([kk[j] for kk in k]))))

    if settings.periodic_boundary:
        for c in ti:
            update.append(Eq(c.indexed[x, y, 0], c.indexed[x, y, nz - 2]))
            update.append(Eq(c.indexed[x, y, nz - 1], c.indexed[x, y, 1]))
            update.append(Eq(c.indexed[x, 0, z], c.indexed[x, ny - 2, z]))
            update.append(Eq(c.indexed[x, ny - 1, z], c.indexed[x, 1, z]))
            update.append(Eq(c.indexed[0, y, z], c.indexed[nx - 2, y, z]))
            update.append(Eq(c.indexed[nx - 1, y, z], c.indexed[1, y, z]))
    else:
        for c in ti:
            update.append(Eq(c.indexed[x, y, 0], 0.))
            update.append(Eq(c.indexed[x, y, nz - 1], 0.))
            update.append(Eq(c.indexed[x, 0, z], 0.))
            update.append(Eq(c.indexed[x, ny - 1, z], 0.))
            update.append(Eq(c.indexed[0, y, z], 0.))
            update.append(Eq(c.indexed[nx - 1, y, z], 0.))
        
    c = 2 / (settings.mu0 * settings.Ms)
    e = Matrix(settings.e)

    zeeman = Matrix(settings.Hdir) * settings.Hmag
    exchange = settings.A * c * vector_laplacian(ti)
    anisotropy = settings.K * c * ti.dot(e) * e
    dmi = settings.D * c * curl(ti)
    heff = zeeman + exchange + anisotropy + dmi

    crossHeff = ti.cross(heff)
    LLG = -settings.gamma0 / (1 + settings.alpha**2) * (crossHeff + settings.alpha * ti.cross(crossHeff))

    for j, kij in enumerate(ki):
        update.append(Eq(kij, LLG[j]))
        
for i, mi in enumerate(m):
    update.append(Eq(mi.forward, solve(mi.dt - Matrix(RKc[-1]).dot(Matrix([kj[i] for kj in k])), mi.forward)[0]))
"""

x, y, z = grid.dimensions
t = grid.stepping_dim

for ki, llgi in zip(k, LLG):
    update.append(Eq(ki.indexed[x, y, z], llgi))
    if settings.periodic_boundary:
        update.append(Eq(ki.indexed[x, y, 0], ki.indexed[x, y, nz - 2]))
        update.append(Eq(ki.indexed[x, y, nz - 1], ki.indexed[x, y, 1]))
        update.append(Eq(ki.indexed[x, 0, z], ki.indexed[x, ny - 2, z]))
        update.append(Eq(ki.indexed[x, ny - 1, z], ki.indexed[x, 1, z]))
        update.append(Eq(ki.indexed[0, y, z], ki.indexed[nx - 2, y, z]))
        update.append(Eq(ki.indexed[nx - 1, y, z], ki.indexed[1, y, z]))
    else:
        update.append(Eq(ki.indexed[x, y, 0], 0.))
        update.append(Eq(ki.indexed[x, y, nz - 1], 0.))
        update.append(Eq(ki.indexed[x, 0, z], 0.))
        update.append(Eq(ki.indexed[x, ny - 1, z], 0.))
        update.append(Eq(ki.indexed[0, y, z], 0.))
        update.append(Eq(ki.indexed[nx - 1, y, z], 0.))
    
for mi, ki in zip(m, k):
    update.append(Eq(mi.indexed[x, y, z], mi.indexed[t, x, y, z] + kc.indexed[0] * ki.indexed[x, y, z] + kc.indexed[t, 1] * ki.indexed[t, x, y, z] + kc.indexed[t - 1, 2] * ki.indexed[t - 1, x, y, z]))
"""
for u in update:
    print(u, file=sys.stderr)
op = Operator(update)
print(op.ccode, file=sys.stderr)
# Out:
# Eq(temp1_x(x, y, z), m_x(t, x, y, z))
# Eq(temp1_y(x, y, z), m_y(t, x, y, z))
# Eq(temp1_z(x, y, z), m_z(t, x, y, z))
# Eq(temp1_x[x, y, 0], temp1_x[x, y, 10])
# Eq(temp1_x[x, y, 11], temp1_x[x, y, 1])
# Eq(temp1_x[x, 0, z], temp1_x[x, 50, z])
# Eq(temp1_x[x, 51, z], temp1_x[x, 1, z])
# Eq(temp1_x[0, y, z], temp1_x[100, y, z])
# Eq(temp1_x[101, y, z], temp1_x[1, y, z])
# Eq(temp1_y[x, y, 0], temp1_y[x, y, 10])
# Eq(temp1_y[x, y, 11], temp1_y[x, y, 1])
# Eq(temp1_y[x, 0, z], temp1_y[x, 50, z])
# Eq(temp1_y[x, 51, z], temp1_y[x, 1, z])
# Eq(temp1_y[0, y, z], temp1_y[100, y, z])
# Eq(temp1_y[101, y, z], temp1_y[1, y, z])
# Eq(temp1_z[x, y, 0], temp1_z[x, y, 10])
# Eq(temp1_z[x, y, 11], temp1_z[x, y, 1])
# Eq(temp1_z[x, 0, z], temp1_z[x, 50, z])
# Eq(temp1_z[x, 51, z], temp1_z[x, 1, z])
# Eq(temp1_z[0, y, z], temp1_z[100, y, z])
# Eq(temp1_z[101, y, z], temp1_z[1, y, z])
# Eq(k1_x(x, y, z), -10785365.8536585*temp1_x(x, y, z)*temp1_z(x, y, z) - 13481707.3170732*temp1_y(x, y, z))
# Eq(k1_y(x, y, z), 13481707.3170732*temp1_x(x, y, z) - 10785365.8536585*temp1_y(x, y, z)*temp1_z(x, y, z))
# Eq(k1_z(x, y, z), 10785365.8536585*temp1_x(x, y, z)**2 + 10785365.8536585*temp1_y(x, y, z)**2)
# Eq(temp2_x(x, y, z), 5.0e-15*k1_x(x, y, z) + m_x(t, x, y, z))
# Eq(temp2_y(x, y, z), 5.0e-15*k1_y(x, y, z) + m_y(t, x, y, z))
# Eq(temp2_z(x, y, z), 5.0e-15*k1_z(x, y, z) + m_z(t, x, y, z))
# Eq(temp2_x[x, y, 0], temp2_x[x, y, 10])
# Eq(temp2_x[x, y, 11], temp2_x[x, y, 1])
# Eq(temp2_x[x, 0, z], temp2_x[x, 50, z])
# Eq(temp2_x[x, 51, z], temp2_x[x, 1, z])
# Eq(temp2_x[0, y, z], temp2_x[100, y, z])
# Eq(temp2_x[101, y, z], temp2_x[1, y, z])
# Eq(temp2_y[x, y, 0], temp2_y[x, y, 10])
# Eq(temp2_y[x, y, 11], temp2_y[x, y, 1])
# Eq(temp2_y[x, 0, z], temp2_y[x, 50, z])
# Eq(temp2_y[x, 51, z], temp2_y[x, 1, z])
# Eq(temp2_y[0, y, z], temp2_y[100, y, z])
# Eq(temp2_y[101, y, z], temp2_y[1, y, z])
# Eq(temp2_z[x, y, 0], temp2_z[x, y, 10])
# Eq(temp2_z[x, y, 11], temp2_z[x, y, 1])
# Eq(temp2_z[x, 0, z], temp2_z[x, 50, z])
# Eq(temp2_z[x, 51, z], temp2_z[x, 1, z])
# Eq(temp2_z[0, y, z], temp2_z[100, y, z])
# Eq(temp2_z[101, y, z], temp2_z[1, y, z])
# Eq(k2_x(x, y, z), -10785365.8536585*temp2_x(x, y, z)*temp2_z(x, y, z) - 13481707.3170732*temp2_y(x, y, z))
# Eq(k2_y(x, y, z), 13481707.3170732*temp2_x(x, y, z) - 10785365.8536585*temp2_y(x, y, z)*temp2_z(x, y, z))
# Eq(k2_z(x, y, z), 10785365.8536585*temp2_x(x, y, z)**2 + 10785365.8536585*temp2_y(x, y, z)**2)
# Eq(temp3_x(x, y, z), 2.0e-14*k1_x(x, y, z) + 1.0e-14*k2_x(x, y, z) + m_x(t, x, y, z))
# Eq(temp3_y(x, y, z), 2.0e-14*k1_y(x, y, z) + 1.0e-14*k2_y(x, y, z) + m_y(t, x, y, z))
# Eq(temp3_z(x, y, z), 2.0e-14*k1_z(x, y, z) + 1.0e-14*k2_z(x, y, z) + m_z(t, x, y, z))
# Eq(temp3_x[x, y, 0], temp3_x[x, y, 10])
# Eq(temp3_x[x, y, 11], temp3_x[x, y, 1])
# Eq(temp3_x[x, 0, z], temp3_x[x, 50, z])
# Eq(temp3_x[x, 51, z], temp3_x[x, 1, z])
# Eq(temp3_x[0, y, z], temp3_x[100, y, z])
# Eq(temp3_x[101, y, z], temp3_x[1, y, z])
# Eq(temp3_y[x, y, 0], temp3_y[x, y, 10])
# Eq(temp3_y[x, y, 11], temp3_y[x, y, 1])
# Eq(temp3_y[x, 0, z], temp3_y[x, 50, z])
# Eq(temp3_y[x, 51, z], temp3_y[x, 1, z])
# Eq(temp3_y[0, y, z], temp3_y[100, y, z])
# Eq(temp3_y[101, y, z], temp3_y[1, y, z])
# Eq(temp3_z[x, y, 0], temp3_z[x, y, 10])
# Eq(temp3_z[x, y, 11], temp3_z[x, y, 1])
# Eq(temp3_z[x, 0, z], temp3_z[x, 50, z])
# Eq(temp3_z[x, 51, z], temp3_z[x, 1, z])
# Eq(temp3_z[0, y, z], temp3_z[100, y, z])
# Eq(temp3_z[101, y, z], temp3_z[1, y, z])
# Eq(k3_x(x, y, z), -10785365.8536585*temp3_x(x, y, z)*temp3_z(x, y, z) - 13481707.3170732*temp3_y(x, y, z))
# Eq(k3_y(x, y, z), 13481707.3170732*temp3_x(x, y, z) - 10785365.8536585*temp3_y(x, y, z)*temp3_z(x, y, z))
# Eq(k3_z(x, y, z), 10785365.8536585*temp3_x(x, y, z)**2 + 10785365.8536585*temp3_y(x, y, z)**2)
# Eq(m_x(t + dt, x, y, z), 0.166666666666667*dt*k1_x(x, y, z) + 0.666666666666667*dt*k2_x(x, y, z) + 0.166666666666667*dt*k3_x(x, y, z) + m_x(t, x, y, z))
# Eq(m_y(t + dt, x, y, z), 0.166666666666667*dt*k1_y(x, y, z) + 0.666666666666667*dt*k2_y(x, y, z) + 0.166666666666667*dt*k3_y(x, y, z) + m_y(t, x, y, z))
# Eq(m_z(t + dt, x, y, z), 0.166666666666667*dt*k1_z(x, y, z) + 0.666666666666667*dt*k2_z(x, y, z) + 0.166666666666667*dt*k3_z(x, y, z) + m_z(t, x, y, z))
# #define _POSIX_C_SOURCE 200809L
# #include "stdlib.h"
# #include "math.h"
# #include "sys/time.h"
# #include "xmmintrin.h"
# #include "pmmintrin.h"
#
# struct profile
# {
#   double section_0;
#   double section_1;
#   double section_2;
#   double section_3;
#   double section_4;
#   double section_5;
#   double section_6;
#   double section_7;
#   double section_8;
#   double section_9;
#   double section_10;
#   double section_11;
#   double section_12;
#   double section_13;
#   double section_14;
#   double section_15;
#   double section_16;
#   double section_17;
#   double section_18;
#   double section_19;
#   double section_20;
#   double section_21;
#   double section_22;
#   double section_23;
#   double section_24;
#   double section_25;
#   double section_26;
#   double section_27;
#   double section_28;
#   double section_29;
#   double section_30;
#   double section_31;
#   double section_32;
#   double section_33;
# } ;
#
# void f_0(const int x_start, const int x_finish, const int y_start, const int y_finish, const int z_start, const int z_finish, float *restrict k1_x_vec, float *restrict k1_y_vec, float *restrict k1_z_vec, float *restrict k2_x_vec, float *restrict k2_y_vec, float *restrict k2_z_vec, float *restrict k3_x_vec, float *restrict k3_y_vec, float *restrict k3_z_vec, float *restrict m_x_vec, float *restrict m_y_vec, float *restrict m_z_vec, const float dt, const int t0, const int t1, const int t_size, const int x_size, const int y_size, const int z_size)
# {
#   float (*restrict k1_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k1_x_vec;
#   float (*restrict k1_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k1_y_vec;
#   float (*restrict k1_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k1_z_vec;
#   float (*restrict k2_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k2_x_vec;
#   float (*restrict k2_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k2_y_vec;
#   float (*restrict k2_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k2_z_vec;
#   float (*restrict k3_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k3_x_vec;
#   float (*restrict k3_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k3_y_vec;
#   float (*restrict k3_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k3_z_vec;
#   float (*restrict m_x)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_x_vec;
#   float (*restrict m_y)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_y_vec;
#   float (*restrict m_z)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_z_vec;
#   for (int x = x_start; x < x_finish; x += 1)
#   {
#     for (int y = y_start; y < y_finish; y += 1)
#     {
#       #pragma ivdep
#       #pragma omp simd
#       for (int z = z_start; z < z_finish; z += 1)
#       {
#         m_x[t1][x][y][z] = 6.66666666666667e-1F*dt*k2_x[x][y][z] + 1.66666666666667e-1F*(dt*k1_x[x][y][z] + dt*k3_x[x][y][z]) + m_x[t0][x][y][z];
#         m_y[t1][x][y][z] = 6.66666666666667e-1F*dt*k2_y[x][y][z] + 1.66666666666667e-1F*(dt*k1_y[x][y][z] + dt*k3_y[x][y][z]) + m_y[t0][x][y][z];
#         m_z[t1][x][y][z] = 6.66666666666667e-1F*dt*k2_z[x][y][z] + 1.66666666666667e-1F*(dt*k1_z[x][y][z] + dt*k3_z[x][y][z]) + m_z[t0][x][y][z];
#       }
#     }
#   }
# }
#
# int Kernel(const float dt, float *restrict k1_x_vec, float *restrict k1_y_vec, float *restrict k1_z_vec, float *restrict k2_x_vec, float *restrict k2_y_vec, float *restrict k2_z_vec, float *restrict k3_x_vec, float *restrict k3_y_vec, float *restrict k3_z_vec, float *restrict m_x_vec, float *restrict m_y_vec, float *restrict m_z_vec, float *restrict temp1_x_vec, float *restrict temp1_y_vec, float *restrict temp1_z_vec, float *restrict temp2_x_vec, float *restrict temp2_y_vec, float *restrict temp2_z_vec, float *restrict temp3_x_vec, float *restrict temp3_y_vec, float *restrict temp3_z_vec, const int t_size, const int t_s, const int t_e, const int time_size, const int time_s, const int time_e, const int x_size, const int x_s, const int x_e, const int y_size, const int y_s, const int y_e, const int z_size, const int z_s, const int z_e, void *_timings, const int x0_block_size, const int x0_block_s, const int x0_block_e, const int y0_block_size, const int y0_block_s, const int y0_block_e)
# {
#   float (*restrict k1_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k1_x_vec;
#   float (*restrict k1_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k1_y_vec;
#   float (*restrict k1_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k1_z_vec;
#   float (*restrict k2_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k2_x_vec;
#   float (*restrict k2_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k2_y_vec;
#   float (*restrict k2_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k2_z_vec;
#   float (*restrict k3_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k3_x_vec;
#   float (*restrict k3_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k3_y_vec;
#   float (*restrict k3_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) k3_z_vec;
#   float (*restrict m_x)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_x_vec;
#   float (*restrict m_y)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_y_vec;
#   float (*restrict m_z)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_z_vec;
#   float (*restrict temp1_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp1_x_vec;
#   float (*restrict temp1_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp1_y_vec;
#   float (*restrict temp1_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp1_z_vec;
#   float (*restrict temp2_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp2_x_vec;
#   float (*restrict temp2_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp2_y_vec;
#   float (*restrict temp2_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp2_z_vec;
#   float (*restrict temp3_x)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp3_x_vec;
#   float (*restrict temp3_y)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp3_y_vec;
#   float (*restrict temp3_z)[y_size][z_size] __attribute__((aligned(64))) = (float (*)[y_size][z_size]) temp3_z_vec;
#   struct profile *timings = (struct profile*) _timings;
#   /* Flush denormal numbers to zero in hardware */
#   _MM_SET_DENORMALS_ZERO_MODE(_MM_DENORMALS_ZERO_ON);
#   _MM_SET_FLUSH_ZERO_MODE(_MM_FLUSH_ZERO_ON);
#   #pragma omp parallel
#   {
#     #pragma omp for schedule(static)
#     for (int time = t_s, t0 = (time)%(2), t1 = (time + 1)%(2); time < t_e - 1; time += 1, t0 = (time)%(2), t1 = (time + 1)%(2))
#     {
#       struct timeval start_section_0, end_section_0;
#       gettimeofday(&start_section_0, NULL);
#       for (int x = x_s; x < x_e; x += 1)
#       {
#         for (int y = y_s; y < y_e; y += 1)
#         {
#           #pragma ivdep
#           #pragma omp simd
#           for (int z = z_s; z < z_e; z += 1)
#           {
#             temp1_x[x][y][z] = m_x[t0][x][y][z];
#             temp1_y[x][y][z] = m_y[t0][x][y][z];
#             temp1_z[x][y][z] = m_z[t0][x][y][z];
#           }
#         }
#       }
#       gettimeofday(&end_section_0, NULL);
#       timings->section_0 += (double)(end_section_0.tv_sec-start_section_0.tv_sec)+(double)(end_section_0.tv_usec-start_section_0.tv_usec)/1000000;
#     }
#   }
#   struct timeval start_section_2, end_section_2;
#   gettimeofday(&start_section_2, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp1_x[x][y][0] = temp1_x[x][y][10];
#       temp1_x[x][y][11] = temp1_x[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp1_x[x][0][z] = temp1_x[x][50][z];
#       temp1_x[x][51][z] = temp1_x[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_2, NULL);
#   timings->section_2 += (double)(end_section_2.tv_sec-start_section_2.tv_sec)+(double)(end_section_2.tv_usec-start_section_2.tv_usec)/1000000;
#   struct timeval start_section_3, end_section_3;
#   gettimeofday(&start_section_3, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp1_x[0][y][z] = temp1_x[100][y][z];
#       temp1_x[101][y][z] = temp1_x[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_3, NULL);
#   timings->section_3 += (double)(end_section_3.tv_sec-start_section_3.tv_sec)+(double)(end_section_3.tv_usec-start_section_3.tv_usec)/1000000;
#   struct timeval start_section_5, end_section_5;
#   gettimeofday(&start_section_5, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp1_y[x][y][0] = temp1_y[x][y][10];
#       temp1_y[x][y][11] = temp1_y[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp1_y[x][0][z] = temp1_y[x][50][z];
#       temp1_y[x][51][z] = temp1_y[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_5, NULL);
#   timings->section_5 += (double)(end_section_5.tv_sec-start_section_5.tv_sec)+(double)(end_section_5.tv_usec-start_section_5.tv_usec)/1000000;
#   struct timeval start_section_6, end_section_6;
#   gettimeofday(&start_section_6, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp1_y[0][y][z] = temp1_y[100][y][z];
#       temp1_y[101][y][z] = temp1_y[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_6, NULL);
#   timings->section_6 += (double)(end_section_6.tv_sec-start_section_6.tv_sec)+(double)(end_section_6.tv_usec-start_section_6.tv_usec)/1000000;
#   struct timeval start_section_8, end_section_8;
#   gettimeofday(&start_section_8, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp1_z[x][y][0] = temp1_z[x][y][10];
#       temp1_z[x][y][11] = temp1_z[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp1_z[x][0][z] = temp1_z[x][50][z];
#       temp1_z[x][51][z] = temp1_z[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_8, NULL);
#   timings->section_8 += (double)(end_section_8.tv_sec-start_section_8.tv_sec)+(double)(end_section_8.tv_usec-start_section_8.tv_usec)/1000000;
#   struct timeval start_section_9, end_section_9;
#   gettimeofday(&start_section_9, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp1_z[0][y][z] = temp1_z[100][y][z];
#       temp1_z[101][y][z] = temp1_z[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_9, NULL);
#   timings->section_9 += (double)(end_section_9.tv_sec-start_section_9.tv_sec)+(double)(end_section_9.tv_usec-start_section_9.tv_usec)/1000000;
#   struct timeval start_section_10, end_section_10;
#   gettimeofday(&start_section_10, NULL);
#   #pragma omp parallel
#   {
#     #pragma omp for schedule(static)
#     for (int x = x_s; x < x_e; x += 1)
#     {
#       for (int y = y_s; y < y_e; y += 1)
#       {
#         #pragma ivdep
#         #pragma omp simd
#         for (int z = z_s; z < z_e; z += 1)
#         {
#           k1_x[x][y][z] = -1.07853658536585e+7F*temp1_x[x][y][z]*temp1_z[x][y][z] - 1.34817073170732e+7F*temp1_y[x][y][z];
#           k1_y[x][y][z] = 1.34817073170732e+7F*temp1_x[x][y][z] - 1.07853658536585e+7F*temp1_y[x][y][z]*temp1_z[x][y][z];
#           k1_z[x][y][z] = 1.07853658536585e+7F*(temp1_x[x][y][z]*temp1_x[x][y][z]) + 1.07853658536585e+7F*(temp1_y[x][y][z]*temp1_y[x][y][z]);
#         }
#       }
#     }
#   }
#   gettimeofday(&end_section_10, NULL);
#   timings->section_10 += (double)(end_section_10.tv_sec-start_section_10.tv_sec)+(double)(end_section_10.tv_usec-start_section_10.tv_usec)/1000000;
#   #pragma omp parallel
#   {
#     #pragma omp for schedule(static)
#     for (int time = t_s, t0 = (time)%(2), t1 = (time + 1)%(2); time < t_e - 1; time += 1, t0 = (time)%(2), t1 = (time + 1)%(2))
#     {
#       struct timeval start_section_11, end_section_11;
#       gettimeofday(&start_section_11, NULL);
#       for (int x = x_s; x < x_e; x += 1)
#       {
#         for (int y = y_s; y < y_e; y += 1)
#         {
#           #pragma ivdep
#           #pragma omp simd
#           for (int z = z_s; z < z_e; z += 1)
#           {
#             temp2_x[x][y][z] = 5.0e-15F*k1_x[x][y][z] + m_x[t0][x][y][z];
#             temp2_y[x][y][z] = 5.0e-15F*k1_y[x][y][z] + m_y[t0][x][y][z];
#             temp2_z[x][y][z] = 5.0e-15F*k1_z[x][y][z] + m_z[t0][x][y][z];
#           }
#         }
#       }
#       gettimeofday(&end_section_11, NULL);
#       timings->section_11 += (double)(end_section_11.tv_sec-start_section_11.tv_sec)+(double)(end_section_11.tv_usec-start_section_11.tv_usec)/1000000;
#     }
#   }
#   struct timeval start_section_13, end_section_13;
#   gettimeofday(&start_section_13, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp2_x[x][y][0] = temp2_x[x][y][10];
#       temp2_x[x][y][11] = temp2_x[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp2_x[x][0][z] = temp2_x[x][50][z];
#       temp2_x[x][51][z] = temp2_x[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_13, NULL);
#   timings->section_13 += (double)(end_section_13.tv_sec-start_section_13.tv_sec)+(double)(end_section_13.tv_usec-start_section_13.tv_usec)/1000000;
#   struct timeval start_section_14, end_section_14;
#   gettimeofday(&start_section_14, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp2_x[0][y][z] = temp2_x[100][y][z];
#       temp2_x[101][y][z] = temp2_x[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_14, NULL);
#   timings->section_14 += (double)(end_section_14.tv_sec-start_section_14.tv_sec)+(double)(end_section_14.tv_usec-start_section_14.tv_usec)/1000000;
#   struct timeval start_section_16, end_section_16;
#   gettimeofday(&start_section_16, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp2_y[x][y][0] = temp2_y[x][y][10];
#       temp2_y[x][y][11] = temp2_y[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp2_y[x][0][z] = temp2_y[x][50][z];
#       temp2_y[x][51][z] = temp2_y[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_16, NULL);
#   timings->section_16 += (double)(end_section_16.tv_sec-start_section_16.tv_sec)+(double)(end_section_16.tv_usec-start_section_16.tv_usec)/1000000;
#   struct timeval start_section_17, end_section_17;
#   gettimeofday(&start_section_17, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp2_y[0][y][z] = temp2_y[100][y][z];
#       temp2_y[101][y][z] = temp2_y[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_17, NULL);
#   timings->section_17 += (double)(end_section_17.tv_sec-start_section_17.tv_sec)+(double)(end_section_17.tv_usec-start_section_17.tv_usec)/1000000;
#   struct timeval start_section_19, end_section_19;
#   gettimeofday(&start_section_19, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp2_z[x][y][0] = temp2_z[x][y][10];
#       temp2_z[x][y][11] = temp2_z[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp2_z[x][0][z] = temp2_z[x][50][z];
#       temp2_z[x][51][z] = temp2_z[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_19, NULL);
#   timings->section_19 += (double)(end_section_19.tv_sec-start_section_19.tv_sec)+(double)(end_section_19.tv_usec-start_section_19.tv_usec)/1000000;
#   struct timeval start_section_20, end_section_20;
#   gettimeofday(&start_section_20, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp2_z[0][y][z] = temp2_z[100][y][z];
#       temp2_z[101][y][z] = temp2_z[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_20, NULL);
#   timings->section_20 += (double)(end_section_20.tv_sec-start_section_20.tv_sec)+(double)(end_section_20.tv_usec-start_section_20.tv_usec)/1000000;
#   struct timeval start_section_21, end_section_21;
#   gettimeofday(&start_section_21, NULL);
#   #pragma omp parallel
#   {
#     #pragma omp for schedule(static)
#     for (int x = x_s; x < x_e; x += 1)
#     {
#       for (int y = y_s; y < y_e; y += 1)
#       {
#         #pragma ivdep
#         #pragma omp simd
#         for (int z = z_s; z < z_e; z += 1)
#         {
#           k2_x[x][y][z] = -1.07853658536585e+7F*temp2_x[x][y][z]*temp2_z[x][y][z] - 1.34817073170732e+7F*temp2_y[x][y][z];
#           k2_y[x][y][z] = 1.34817073170732e+7F*temp2_x[x][y][z] - 1.07853658536585e+7F*temp2_y[x][y][z]*temp2_z[x][y][z];
#           k2_z[x][y][z] = 1.07853658536585e+7F*(temp2_x[x][y][z]*temp2_x[x][y][z]) + 1.07853658536585e+7F*(temp2_y[x][y][z]*temp2_y[x][y][z]);
#         }
#       }
#     }
#   }
#   gettimeofday(&end_section_21, NULL);
#   timings->section_21 += (double)(end_section_21.tv_sec-start_section_21.tv_sec)+(double)(end_section_21.tv_usec-start_section_21.tv_usec)/1000000;
#   #pragma omp parallel
#   {
#     #pragma omp for schedule(static)
#     for (int time = t_s, t0 = (time)%(2), t1 = (time + 1)%(2); time < t_e - 1; time += 1, t0 = (time)%(2), t1 = (time + 1)%(2))
#     {
#       struct timeval start_section_22, end_section_22;
#       gettimeofday(&start_section_22, NULL);
#       for (int x = x_s; x < x_e; x += 1)
#       {
#         for (int y = y_s; y < y_e; y += 1)
#         {
#           #pragma ivdep
#           #pragma omp simd
#           for (int z = z_s; z < z_e; z += 1)
#           {
#             temp3_x[x][y][z] = 2.0e-14F*k1_x[x][y][z] + 1.0e-14F*k2_x[x][y][z] + m_x[t0][x][y][z];
#             temp3_y[x][y][z] = 2.0e-14F*k1_y[x][y][z] + 1.0e-14F*k2_y[x][y][z] + m_y[t0][x][y][z];
#             temp3_z[x][y][z] = 2.0e-14F*k1_z[x][y][z] + 1.0e-14F*k2_z[x][y][z] + m_z[t0][x][y][z];
#           }
#         }
#       }
#       gettimeofday(&end_section_22, NULL);
#       timings->section_22 += (double)(end_section_22.tv_sec-start_section_22.tv_sec)+(double)(end_section_22.tv_usec-start_section_22.tv_usec)/1000000;
#     }
#   }
#   struct timeval start_section_24, end_section_24;
#   gettimeofday(&start_section_24, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp3_x[x][y][0] = temp3_x[x][y][10];
#       temp3_x[x][y][11] = temp3_x[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp3_x[x][0][z] = temp3_x[x][50][z];
#       temp3_x[x][51][z] = temp3_x[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_24, NULL);
#   timings->section_24 += (double)(end_section_24.tv_sec-start_section_24.tv_sec)+(double)(end_section_24.tv_usec-start_section_24.tv_usec)/1000000;
#   struct timeval start_section_25, end_section_25;
#   gettimeofday(&start_section_25, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp3_x[0][y][z] = temp3_x[100][y][z];
#       temp3_x[101][y][z] = temp3_x[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_25, NULL);
#   timings->section_25 += (double)(end_section_25.tv_sec-start_section_25.tv_sec)+(double)(end_section_25.tv_usec-start_section_25.tv_usec)/1000000;
#   struct timeval start_section_27, end_section_27;
#   gettimeofday(&start_section_27, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp3_y[x][y][0] = temp3_y[x][y][10];
#       temp3_y[x][y][11] = temp3_y[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp3_y[x][0][z] = temp3_y[x][50][z];
#       temp3_y[x][51][z] = temp3_y[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_27, NULL);
#   timings->section_27 += (double)(end_section_27.tv_sec-start_section_27.tv_sec)+(double)(end_section_27.tv_usec-start_section_27.tv_usec)/1000000;
#   struct timeval start_section_28, end_section_28;
#   gettimeofday(&start_section_28, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp3_y[0][y][z] = temp3_y[100][y][z];
#       temp3_y[101][y][z] = temp3_y[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_28, NULL);
#   timings->section_28 += (double)(end_section_28.tv_sec-start_section_28.tv_sec)+(double)(end_section_28.tv_usec-start_section_28.tv_usec)/1000000;
#   struct timeval start_section_30, end_section_30;
#   gettimeofday(&start_section_30, NULL);
#   for (int x = x_s; x < x_e; x += 1)
#   {
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       temp3_z[x][y][0] = temp3_z[x][y][10];
#       temp3_z[x][y][11] = temp3_z[x][y][1];
#     }
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp3_z[x][0][z] = temp3_z[x][50][z];
#       temp3_z[x][51][z] = temp3_z[x][1][z];
#     }
#   }
#   gettimeofday(&end_section_30, NULL);
#   timings->section_30 += (double)(end_section_30.tv_sec-start_section_30.tv_sec)+(double)(end_section_30.tv_usec-start_section_30.tv_usec)/1000000;
#   struct timeval start_section_31, end_section_31;
#   gettimeofday(&start_section_31, NULL);
#   for (int y = y_s; y < y_e; y += 1)
#   {
#     for (int z = z_s; z < z_e; z += 1)
#     {
#       temp3_z[0][y][z] = temp3_z[100][y][z];
#       temp3_z[101][y][z] = temp3_z[1][y][z];
#     }
#   }
#   gettimeofday(&end_section_31, NULL);
#   timings->section_31 += (double)(end_section_31.tv_sec-start_section_31.tv_sec)+(double)(end_section_31.tv_usec-start_section_31.tv_usec)/1000000;
#   struct timeval start_section_32, end_section_32;
#   gettimeofday(&start_section_32, NULL);
#   #pragma omp parallel
#   {
#     #pragma omp for schedule(static)
#     for (int x = x_s; x < x_e; x += 1)
#     {
#       for (int y = y_s; y < y_e; y += 1)
#       {
#         #pragma ivdep
#         #pragma omp simd
#         for (int z = z_s; z < z_e; z += 1)
#         {
#           k3_x[x][y][z] = -1.07853658536585e+7F*temp3_x[x][y][z]*temp3_z[x][y][z] - 1.34817073170732e+7F*temp3_y[x][y][z];
#           k3_y[x][y][z] = 1.34817073170732e+7F*temp3_x[x][y][z] - 1.07853658536585e+7F*temp3_y[x][y][z]*temp3_z[x][y][z];
#           k3_z[x][y][z] = 1.07853658536585e+7F*(temp3_x[x][y][z]*temp3_x[x][y][z]) + 1.07853658536585e+7F*(temp3_y[x][y][z]*temp3_y[x][y][z]);
#         }
#       }
#     }
#   }
#   gettimeofday(&end_section_32, NULL);
#   timings->section_32 += (double)(end_section_32.tv_sec-start_section_32.tv_sec)+(double)(end_section_32.tv_usec-start_section_32.tv_usec)/1000000;
#   for (int time = t_s, t0 = (time)%(2), t1 = (time + 1)%(2); time < t_e - 1; time += 1, t0 = (time)%(2), t1 = (time + 1)%(2))
#   {
#     struct timeval start_section_33, end_section_33;
#     gettimeofday(&start_section_33, NULL);
#     #pragma omp parallel
#     {
#       #pragma omp for schedule(static)
#       for (int x0_block = x_s; x0_block < x_e - (x_e - x_s)%(x0_block_size); x0_block += x0_block_size)
#       {
#         for (int y0_block = y_s; y0_block < y_e - (y_e - y_s)%(y0_block_size); y0_block += y0_block_size)
#         {
#           #pragma noinline
#           f_0(x0_block,x0_block + x0_block_size,y0_block,y0_block + y0_block_size,z_s,z_e,k1_x_vec,k1_y_vec,k1_z_vec,k2_x_vec,k2_y_vec,k2_z_vec,k3_x_vec,k3_y_vec,k3_z_vec,m_x_vec,m_y_vec,m_z_vec,dt,t0,t1,t_size,x_size,y_size,z_size);
#         }
#       }
#       #pragma omp for schedule(static)
#       for (int y0_block = y_s; y0_block < y_e - (y_e - y_s)%(y0_block_size); y0_block += y0_block_size)
#       {
#         #pragma noinline
#         f_0(x_e - (x_e - x_s)%(x0_block_size),x_e,y0_block,y0_block + y0_block_size,z_s,z_e,k1_x_vec,k1_y_vec,k1_z_vec,k2_x_vec,k2_y_vec,k2_z_vec,k3_x_vec,k3_y_vec,k3_z_vec,m_x_vec,m_y_vec,m_z_vec,dt,t0,t1,t_size,x_size,y_size,z_size);
#       }
#       #pragma omp for schedule(static)
#       for (int x0_block = x_s; x0_block < x_e - (x_e - x_s)%(x0_block_size); x0_block += x0_block_size)
#       {
#         #pragma noinline
#         f_0(x0_block,x0_block + x0_block_size,y_e - (y_e - y_s)%(y0_block_size),y_e,z_s,z_e,k1_x_vec,k1_y_vec,k1_z_vec,k2_x_vec,k2_y_vec,k2_z_vec,k3_x_vec,k3_y_vec,k3_z_vec,m_x_vec,m_y_vec,m_z_vec,dt,t0,t1,t_size,x_size,y_size,z_size);
#       }
#     }
#     #pragma noinline
#     f_0(x_e - (x_e - x_s)%(x0_block_size),x_e,y_e - (y_e - y_s)%(y0_block_size),y_e,z_s,z_e,k1_x_vec,k1_y_vec,k1_z_vec,k2_x_vec,k2_y_vec,k2_z_vec,k3_x_vec,k3_y_vec,k3_z_vec,m_x_vec,m_y_vec,m_z_vec,dt,t0,t1,t_size,x_size,y_size,z_size);
#     gettimeofday(&end_section_33, NULL);
#     timings->section_33 += (double)(end_section_33.tv_sec-start_section_33.tv_sec)+(double)(end_section_33.tv_usec-start_section_33.tv_usec)/1000000;
#   }
#   return 0;
# }

# %%
print("Compiling code ...", file=sys.stderr)
op.cfunction # compile
# Out:
# Compiling code ...
# FAILED compiler invocation:icc -O3 -g -fPIC -Wall -std=c99 -xhost -shared -qopenmp /tmp/devito-1esf54z2/929d9d202bbc26f74934a07a7b07cc93258431c6.c -o /tmp/devito-1esf54z2/929d9d202bbc26f74934a07a7b07cc93258431c6.so
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# <ipython-input-8-179fd7b79440> in <module>()
#       1 print("Compiling code ...", file=sys.stderr)
# ----> 2 op.cfunction # compile
#
# ~/devito/devito/operator.py in cfunction(self)
#     273         """Returns the JIT-compiled C function as a ctypes.FuncPtr object."""
#     274         if self._lib is None:
# --> 275             basename = self.compile
#     276             self._lib = load(basename, self._compiler)
#     277             self._lib.name = basename
#
# ~/devito/devito/operator.py in compile(self)
#     265         if self._lib is None:
#     266             # No need to recompile if a shared object has already been loaded.
# --> 267             return jit_compile(self.ccode, self._compiler)
#     268         else:
#     269             return self._lib.name
#
# ~/devito/devito/compiler.py in jit_compile(ccode, compiler)
#     246     extension_file_from_string(toolchain=compiler, ext_file=lib_file,
#     247                                source_string=ccode, source_name=src_file,
# --> 248                                debug=configuration['debug_compiler'])
#     249     toc = time()
#     250     log("%s: compiled %s [%.2f s]" % (compiler, src_file, toc-tic))
#
# /opt/conda/lib/python3.6/site-packages/codepy/jit.py in extension_file_from_string(toolchain, ext_file, source_string, source_name, debug)
#      63
#      64     try:
# ---> 65         toolchain.build_extension(ext_file, [source_file], debug=debug)
#      66     finally:
#      67         _erase_dir(src_dir)
#
# /opt/conda/lib/python3.6/site-packages/codepy/toolchain.py in build_extension(self, ext_file, source_files, debug)
#     208             print("FAILED compiler invocation:" + " ".join(cc_cmdline),
#     209                   file=sys.stderr)
# --> 210             raise CompileError("module compilation failed")
#     211
#     212     def link_extension(self, ext_file, object_files, debug=False):
#
# CompileError: module compilation failed
