# %%
class Struct(object):
    def __init__(self, kwargs):
        for k, v in kwargs.items():
            self.__dict__[k] = Struct(v) if isinstance(v, dict) else v
            
settings = Struct({'A': 0,
 'D': 0,
 'H': (0.0, 0.0, 100.0),
 'Hdir': (0, 0, 1),
 'Hmag': 100.0,
 'K': 0,
 'Ms': 800000.0,
 'alpha': 0.8,
 'correction': 0,
 'e': (1, 0, 0),
 'frames': 10,
 'gamma0': 221100.0,
 'grid': {'d': (1e-09, 1e-09, 1e-09),
  'l': (1.0000000000000001e-07, 5.0000000000000004e-08, 1e-08),
  'n': (100, 50, 10)},
 'init': 'flower',
 'mu0': 1.2566370614e-06,
 'periodic_boundary': True,
 'save_every': 100,
 'time': {'d': 1e-14, 'l': 1e-11, 'n': 1000},
 'value': None})

# %%
import os
import sys

if not "DEVITO_OPENMP" in os.environ or os.environ["DEVITO_OPENMP"] != "1":
    print("*** WARNING: Devito OpenMP environment variable has not been set ***", file=sys.stderr)
os.environ['OMP_NUM_THREADS'] = "8"

import numpy as np
from sympy import Matrix, Eq, solve
from devito import Grid, Function, TimeFunction, configuration, Operator

def vector_laplacian(u):
    return Matrix([u[0].dx2 + u[0].dy2 + u[0].dz2,
                   u[1].dx2 + u[1].dy2 + u[1].dz2,
                   u[2].dx2 + u[2].dy2 + u[2].dz2])

def vector_gradient(u):
    return u[0].dx**2 + u[0].dy**2 + u[0].dz**2 + u[1].dx**2 + u[1].dy**2 + u[1].dz**2 + u[2].dx**2 + u[2].dy**2 + u[2].dz**2

def curl(u):
    return Matrix([u[2].dy - u[1].dz,
                   u[0].dz - u[2].dx,
                   u[1].dx - u[0].dy])

def VectorTimeFunction(name, settings):
    return Matrix([TimeFunction(name='{}_x'.format(name), **settings), TimeFunction(name='{}_y'.format(name), **settings), TimeFunction(name='{}_z'.format(name), **settings)])


def VectorDenseData(name, settings):
    return Matrix([Function(name='{}_x'.format(name), **settings), Function(name='{}_y'.format(name), **settings), Function(name='{}_z'.format(name), **settings)])

buffer_params = Struct({'buffer_dims': (102, 52, 12),
 'buffer_slice': (slice(1, -1, None), slice(1, -1, None), slice(1, -1, None)),
 'data_dims': (100, 50, 10)})

# %%
RKc = [[0, 0, 0], [0.5, 0, 0], [2, 1, 0], [1/6, 2/3, 1/6]]

grid = Grid(shape=buffer_params.buffer_dims, extent=settings.grid.l)
m = VectorTimeFunction('m', {"grid":grid, "space_order":2, "time_order":3})
k = VectorTimeFunction('k', {"grid":grid, "space_order":2, "time_order":3})
kc = TimeFunction(name='kc', **{"grid":Grid(shape=(3,)), "space_order":1, "time_order":3})

kc.data[:] = np.array(RKc)

nx, ny, nz = buffer_params.buffer_dims
dt = settings.time.d
update = []

c = 2 / (settings.mu0 * settings.Ms)
e = Matrix(settings.e)

zeeman = Matrix(settings.Hdir) * settings.Hmag
exchange = settings.A * c * vector_laplacian(m)
anisotropy = settings.K * c * m.dot(e) * e
dmi = settings.D * c * curl(m)
heff = zeeman + exchange + anisotropy + dmi

crossHeff = m.cross(heff)
LLG = -settings.gamma0 / (1 + settings.alpha**2) * (crossHeff + settings.alpha * m.cross(crossHeff))

x, y, z = grid.dimensions
t = grid.stepping_dim

for ki, llgi in zip(k, LLG):
    update.append(Eq(ki.indexed[t + 1, x, y, z], llgi))
    if settings.periodic_boundary:
        update.append(Eq(ki.indexed[t + 1, x, y, 0], ki.indexed[t + 1, x, y, nz - 2]))
        update.append(Eq(ki.indexed[t + 1, x, y, nz - 1], ki.indexed[t + 1, x, y, 1]))
        update.append(Eq(ki.indexed[t + 1, x, 0, z], ki.indexed[t + 1, x, ny - 2, z]))
        update.append(Eq(ki.indexed[t + 1, x, ny - 1, z], ki.indexed[t + 1, x, 1, z]))
        update.append(Eq(ki.indexed[t + 1, 0, y, z], ki.indexed[t + 1, nx - 2, y, z]))
        update.append(Eq(ki.indexed[t + 1, nx - 1, y, z], ki.indexed[t + 1, 1, y, z]))
    else:
        update.append(Eq(ki.indexed[t + 1, x, y, 0], 0.))
        update.append(Eq(ki.indexed[t + 1, x, y, nz - 1], 0.))
        update.append(Eq(ki.indexed[t + 1, x, 0, z], 0.))
        update.append(Eq(ki.indexed[t + 1, x, ny - 1, z], 0.))
        update.append(Eq(ki.indexed[t + 1, 0, y, z], 0.))
        update.append(Eq(ki.indexed[t + 1, nx - 1, y, z], 0.))
    
for mi, ki in zip(m, k):
    update.append(Eq(mi.indexed[t + 1, x, y, z], mi.indexed[t, x, y, z] + kc.indexed[t + 1, 0] * ki.indexed[t + 1, x, y, z] + kc.indexed[t, 1] * ki.indexed[t, x, y, z] + kc.indexed[t - 1, 2] * ki.indexed[t - 1, x, y, z]))

for u in update:
    print(u, file=sys.stderr)
op = Operator(update)
print(op.ccode, file=sys.stderr)
# Out:
# Eq(k_x[t + 1, x, y, z], -10785365.8536585*m_x(t, x, y, z)*m_z(t, x, y, z) - 13481707.3170732*m_y(t, x, y, z))
# Eq(k_x[t + 1, x, y, 0], k_x[t + 1, x, y, 10])
# Eq(k_x[t + 1, x, y, 11], k_x[t + 1, x, y, 1])
# Eq(k_x[t + 1, x, 0, z], k_x[t + 1, x, 50, z])
# Eq(k_x[t + 1, x, 51, z], k_x[t + 1, x, 1, z])
# Eq(k_x[t + 1, 0, y, z], k_x[t + 1, 100, y, z])
# Eq(k_x[t + 1, 101, y, z], k_x[t + 1, 1, y, z])
# Eq(k_y[t + 1, x, y, z], 13481707.3170732*m_x(t, x, y, z) - 10785365.8536585*m_y(t, x, y, z)*m_z(t, x, y, z))
# Eq(k_y[t + 1, x, y, 0], k_y[t + 1, x, y, 10])
# Eq(k_y[t + 1, x, y, 11], k_y[t + 1, x, y, 1])
# Eq(k_y[t + 1, x, 0, z], k_y[t + 1, x, 50, z])
# Eq(k_y[t + 1, x, 51, z], k_y[t + 1, x, 1, z])
# Eq(k_y[t + 1, 0, y, z], k_y[t + 1, 100, y, z])
# Eq(k_y[t + 1, 101, y, z], k_y[t + 1, 1, y, z])
# Eq(k_z[t + 1, x, y, z], 10785365.8536585*m_x(t, x, y, z)**2 + 10785365.8536585*m_y(t, x, y, z)**2)
# Eq(k_z[t + 1, x, y, 0], k_z[t + 1, x, y, 10])
# Eq(k_z[t + 1, x, y, 11], k_z[t + 1, x, y, 1])
# Eq(k_z[t + 1, x, 0, z], k_z[t + 1, x, 50, z])
# Eq(k_z[t + 1, x, 51, z], k_z[t + 1, x, 1, z])
# Eq(k_z[t + 1, 0, y, z], k_z[t + 1, 100, y, z])
# Eq(k_z[t + 1, 101, y, z], k_z[t + 1, 1, y, z])
# Eq(m_x[t + 1, x, y, z], kc[t, 1]*k_x[t, x, y, z] + kc[t - 1, 2]*k_x[t - 1, x, y, z] + kc[t + 1, 0]*k_x[t + 1, x, y, z] + m_x[t, x, y, z])
# Eq(m_y[t + 1, x, y, z], kc[t, 1]*k_y[t, x, y, z] + kc[t - 1, 2]*k_y[t - 1, x, y, z] + kc[t + 1, 0]*k_y[t + 1, x, y, z] + m_y[t, x, y, z])
# Eq(m_z[t + 1, x, y, z], kc[t, 1]*k_z[t, x, y, z] + kc[t - 1, 2]*k_z[t - 1, x, y, z] + kc[t + 1, 0]*k_z[t + 1, x, y, z] + m_z[t, x, y, z])
# #define _POSIX_C_SOURCE 200809L
# #include "stdlib.h"
# #include "math.h"
# #include "sys/time.h"
# #include "xmmintrin.h"
# #include "pmmintrin.h"
#
# struct profile
# {
#   double section_0;
#   double section_1;
#   double section_2;
#   double section_3;
#   double section_4;
#   double section_5;
#   double section_6;
#   double section_7;
#   double section_8;
#   double section_9;
#   double section_10;
#   double section_11;
#   double section_12;
# } ;
#
# void f_0(const int x_start, const int x_finish, const int y_start, const int y_finish, const int z_start, const int z_finish, float *restrict k_x_vec, float *restrict k_y_vec, float *restrict k_z_vec, float *restrict kc_vec, float *restrict m_x_vec, float *restrict m_y_vec, float *restrict m_z_vec, const int t0, const int t1, const int t2, const int t_size, const int x_size, const int y_size, const int z_size)
# {
#   float (*restrict k_x)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) k_x_vec;
#   float (*restrict k_y)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) k_y_vec;
#   float (*restrict k_z)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) k_z_vec;
#   float (*restrict kc)[x_size] __attribute__((aligned(64))) = (float (*)[x_size]) kc_vec;
#   float (*restrict m_x)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_x_vec;
#   float (*restrict m_y)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_y_vec;
#   float (*restrict m_z)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_z_vec;
#   for (int x = x_start; x < x_finish; x += 1)
#   {
#     for (int y = y_start; y < y_finish; y += 1)
#     {
#       #pragma ivdep
#       #pragma omp simd
#       for (int z = z_start; z < z_finish; z += 1)
#       {
#         m_x[t1][x][y][z] = kc[t0][1]*k_x[t0][x][y][z] + kc[t1][0]*k_x[t1][x][y][z] + kc[t2][2]*k_x[t2][x][y][z] + m_x[t0][x][y][z];
#         m_y[t1][x][y][z] = kc[t0][1]*k_y[t0][x][y][z] + kc[t1][0]*k_y[t1][x][y][z] + kc[t2][2]*k_y[t2][x][y][z] + m_y[t0][x][y][z];
#         m_z[t1][x][y][z] = kc[t0][1]*k_z[t0][x][y][z] + kc[t1][0]*k_z[t1][x][y][z] + kc[t2][2]*k_z[t2][x][y][z] + m_z[t0][x][y][z];
#       }
#     }
#   }
# }
#
# int Kernel(float *restrict k_x_vec, float *restrict k_y_vec, float *restrict k_z_vec, float *restrict kc_vec, float *restrict m_x_vec, float *restrict m_y_vec, float *restrict m_z_vec, const int t_size, const int t_s, const int t_e, const int time_size, const int time_s, const int time_e, const int x_size, const int x_s, const int x_e, const int y_size, const int y_s, const int y_e, const int z_size, const int z_s, const int z_e, void *_timings, const int x0_block_size, const int x0_block_s, const int x0_block_e, const int y0_block_size, const int y0_block_s, const int y0_block_e)
# {
#   float (*restrict k_x)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) k_x_vec;
#   float (*restrict k_y)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) k_y_vec;
#   float (*restrict k_z)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) k_z_vec;
#   float (*restrict kc)[x_size] __attribute__((aligned(64))) = (float (*)[x_size]) kc_vec;
#   float (*restrict m_x)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_x_vec;
#   float (*restrict m_y)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_y_vec;
#   float (*restrict m_z)[x_size][y_size][z_size] __attribute__((aligned(64))) = (float (*)[x_size][y_size][z_size]) m_z_vec;
#   struct profile *timings = (struct profile*) _timings;
#   /* Flush denormal numbers to zero in hardware */
#   _MM_SET_DENORMALS_ZERO_MODE(_MM_DENORMALS_ZERO_ON);
#   _MM_SET_FLUSH_ZERO_MODE(_MM_FLUSH_ZERO_ON);
#   for (int time = t_s + 1, t0 = (time)%(4), t1 = (time + 1)%(4), t2 = (time + 3)%(4); time < t_e - 1; time += 1, t0 = (time)%(4), t1 = (time + 1)%(4), t2 = (time + 3)%(4))
#   {
#     struct timeval start_section_2, end_section_2;
#     gettimeofday(&start_section_2, NULL);
#     for (int x = x_s; x < x_e; x += 1)
#     {
#       for (int y = y_s; y < y_e; y += 1)
#       {
#         #pragma omp parallel
#         {
#           #pragma omp for schedule(static)
#           for (int z = z_s; z < z_e; z += 1)
#           {
#             k_x[t1][x][y][z] = -1.07853658536585e+7F*m_x[t0][x][y][z]*m_z[t0][x][y][z] - 1.34817073170732e+7F*m_y[t0][x][y][z];
#           }
#         }
#         k_x[t1][x][y][0] = k_x[t1][x][y][10];
#         k_x[t1][x][y][11] = k_x[t1][x][y][1];
#       }
#       for (int z = z_s; z < z_e; z += 1)
#       {
#         k_x[t1][x][0][z] = k_x[t1][x][50][z];
#         k_x[t1][x][51][z] = k_x[t1][x][1][z];
#       }
#     }
#     gettimeofday(&end_section_2, NULL);
#     timings->section_2 += (double)(end_section_2.tv_sec-start_section_2.tv_sec)+(double)(end_section_2.tv_usec-start_section_2.tv_usec)/1000000;
#     struct timeval start_section_3, end_section_3;
#     gettimeofday(&start_section_3, NULL);
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       for (int z = z_s; z < z_e; z += 1)
#       {
#         k_x[t1][0][y][z] = k_x[t1][100][y][z];
#         k_x[t1][101][y][z] = k_x[t1][1][y][z];
#       }
#     }
#     gettimeofday(&end_section_3, NULL);
#     timings->section_3 += (double)(end_section_3.tv_sec-start_section_3.tv_sec)+(double)(end_section_3.tv_usec-start_section_3.tv_usec)/1000000;
#     struct timeval start_section_6, end_section_6;
#     gettimeofday(&start_section_6, NULL);
#     for (int x = x_s; x < x_e; x += 1)
#     {
#       for (int y = y_s; y < y_e; y += 1)
#       {
#         #pragma omp parallel
#         {
#           #pragma omp for schedule(static)
#           for (int z = z_s; z < z_e; z += 1)
#           {
#             k_y[t1][x][y][z] = 1.34817073170732e+7F*m_x[t0][x][y][z] - 1.07853658536585e+7F*m_y[t0][x][y][z]*m_z[t0][x][y][z];
#           }
#         }
#         k_y[t1][x][y][0] = k_y[t1][x][y][10];
#         k_y[t1][x][y][11] = k_y[t1][x][y][1];
#       }
#       for (int z = z_s; z < z_e; z += 1)
#       {
#         k_y[t1][x][0][z] = k_y[t1][x][50][z];
#         k_y[t1][x][51][z] = k_y[t1][x][1][z];
#       }
#     }
#     gettimeofday(&end_section_6, NULL);
#     timings->section_6 += (double)(end_section_6.tv_sec-start_section_6.tv_sec)+(double)(end_section_6.tv_usec-start_section_6.tv_usec)/1000000;
#     struct timeval start_section_7, end_section_7;
#     gettimeofday(&start_section_7, NULL);
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       for (int z = z_s; z < z_e; z += 1)
#       {
#         k_y[t1][0][y][z] = k_y[t1][100][y][z];
#         k_y[t1][101][y][z] = k_y[t1][1][y][z];
#       }
#     }
#     gettimeofday(&end_section_7, NULL);
#     timings->section_7 += (double)(end_section_7.tv_sec-start_section_7.tv_sec)+(double)(end_section_7.tv_usec-start_section_7.tv_usec)/1000000;
#     struct timeval start_section_10, end_section_10;
#     gettimeofday(&start_section_10, NULL);
#     for (int x = x_s; x < x_e; x += 1)
#     {
#       for (int y = y_s; y < y_e; y += 1)
#       {
#         #pragma omp parallel
#         {
#           #pragma omp for schedule(static)
#           for (int z = z_s; z < z_e; z += 1)
#           {
#             k_z[t1][x][y][z] = 1.07853658536585e+7F*(m_x[t0][x][y][z]*m_x[t0][x][y][z] + m_y[t0][x][y][z]*m_y[t0][x][y][z]);
#           }
#         }
#         k_z[t1][x][y][0] = k_z[t1][x][y][10];
#         k_z[t1][x][y][11] = k_z[t1][x][y][1];
#       }
#       for (int z = z_s; z < z_e; z += 1)
#       {
#         k_z[t1][x][0][z] = k_z[t1][x][50][z];
#         k_z[t1][x][51][z] = k_z[t1][x][1][z];
#       }
#     }
#     gettimeofday(&end_section_10, NULL);
#     timings->section_10 += (double)(end_section_10.tv_sec-start_section_10.tv_sec)+(double)(end_section_10.tv_usec-start_section_10.tv_usec)/1000000;
#     struct timeval start_section_11, end_section_11;
#     gettimeofday(&start_section_11, NULL);
#     for (int y = y_s; y < y_e; y += 1)
#     {
#       for (int z = z_s; z < z_e; z += 1)
#       {
#         k_z[t1][0][y][z] = k_z[t1][100][y][z];
#         k_z[t1][101][y][z] = k_z[t1][1][y][z];
#       }
#     }
#     gettimeofday(&end_section_11, NULL);
#     timings->section_11 += (double)(end_section_11.tv_sec-start_section_11.tv_sec)+(double)(end_section_11.tv_usec-start_section_11.tv_usec)/1000000;
#     struct timeval start_section_12, end_section_12;
#     gettimeofday(&start_section_12, NULL);
#     #pragma omp parallel
#     {
#       #pragma omp for schedule(static)
#       for (int x0_block = x_s; x0_block < x_e - (x_e - x_s)%(x0_block_size); x0_block += x0_block_size)
#       {
#         for (int y0_block = y_s; y0_block < y_e - (y_e - y_s)%(y0_block_size); y0_block += y0_block_size)
#         {
#           #pragma noinline
#           f_0(x0_block,x0_block + x0_block_size,y0_block,y0_block + y0_block_size,z_s,z_e,k_x_vec,k_y_vec,k_z_vec,kc_vec,m_x_vec,m_y_vec,m_z_vec,t0,t1,t2,t_size,x_size,y_size,z_size);
#         }
#       }
#       #pragma omp for schedule(static)
#       for (int y0_block = y_s; y0_block < y_e - (y_e - y_s)%(y0_block_size); y0_block += y0_block_size)
#       {
#         #pragma noinline
#         f_0(x_e - (x_e - x_s)%(x0_block_size),x_e,y0_block,y0_block + y0_block_size,z_s,z_e,k_x_vec,k_y_vec,k_z_vec,kc_vec,m_x_vec,m_y_vec,m_z_vec,t0,t1,t2,t_size,x_size,y_size,z_size);
#       }
#       #pragma omp for schedule(static)
#       for (int x0_block = x_s; x0_block < x_e - (x_e - x_s)%(x0_block_size); x0_block += x0_block_size)
#       {
#         #pragma noinline
#         f_0(x0_block,x0_block + x0_block_size,y_e - (y_e - y_s)%(y0_block_size),y_e,z_s,z_e,k_x_vec,k_y_vec,k_z_vec,kc_vec,m_x_vec,m_y_vec,m_z_vec,t0,t1,t2,t_size,x_size,y_size,z_size);
#       }
#     }
#     #pragma noinline
#     f_0(x_e - (x_e - x_s)%(x0_block_size),x_e,y_e - (y_e - y_s)%(y0_block_size),y_e,z_s,z_e,k_x_vec,k_y_vec,k_z_vec,kc_vec,m_x_vec,m_y_vec,m_z_vec,t0,t1,t2,t_size,x_size,y_size,z_size);
#     gettimeofday(&end_section_12, NULL);
#     timings->section_12 += (double)(end_section_12.tv_sec-start_section_12.tv_sec)+(double)(end_section_12.tv_usec-start_section_12.tv_usec)/1000000;
#   }
#   return 0;
# }
