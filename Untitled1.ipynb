# %%
import discretisedfield as df
m = df.Mesh((0, 0, 0), (1e-9, 1e-9, 1e-9), (1e-9, 1e-9, 1e-13))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
field = df.Field(mesh=m, dim=3, value=(0, 0, 1), name='test')

# %%
field.array.shape
# Out:
# (1, 1, 10000, 3)

# %%
m

# %%
field.plot_plane("z")

# %%
field.write('test.omf')

# %%
f2 = df.read('perf_test4/oommf_temp/m0.omf')

# %%
f2.array.shape
# Out:
# (100, 100, 100, 3)

# %%
f2.array[50,50,50]
# Out:
# array([ nan,  nan,  nan])
